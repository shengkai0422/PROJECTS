# %% [markdown]
# # job searching on monster.com

# %%
import requests 
import json 
from bs4 import BeautifulSoup

# %%
payload={}
headers={}

# %%
my_url='https://www.monster.com/jobs/search/?q=python-developer&where=Bridgeport'
response=requests.get(my_url,headers=headers,data=payload)

# %%
print(response.text.encode('utf8'))
# Out:
# b'<!DOCTYPE html>\r\n<html xmlns="https://www.w3.org/1999/xhtml" xml:lang="en" lang="en">\r\n<head>\r\n    \r\n<meta http-equiv="X-UA-Compatible" content="IE=edge" />\r\n<meta http-equiv="Expires" content="0" />\r\n<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=2.0, minimum-scale=1" />\r\n<meta name="j_jp" content="1" />\r\n<meta charset="UTF-8">\r\n<title>Python Developer Jobs in Bridgeport, AL. Bridgeport Python Developer Jobs | Monster.com</title>\r\n\r\n        <style type="text/css">\r\n                @font-face{font-family:\'Roboto\';font-style:normal;font-weight:100;font-display:optional;src:local(\'Roboto Thin\'),local(\'Roboto-Thin\'),local(\'sans-serif-thin\'),url(https://fonts.gstatic.com/s/roboto/v19/KFOkCnqEu92Fr1MmgVxFIzIXKMnyrYk.woff2) format(\'woff2\');unicode-range:U+0460-052F,U+1C80-1C88,U+20B4,U+2DE0-2DFF,U+A640-A69F,U+FE2E-FE2F}@font-face{font-family:\'Roboto\';font-style:normal;font-weight:100;font-display:optional;src:local(
# ...

# %%
soupe=BeautifulSoupe
